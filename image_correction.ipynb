# %%
from PIL import Image, ImageDraw, ImageFont

# Load the Similarity Explanation image
image_path = 'userstudy_images/01_carousel_SimiExpl_False.png'
image = Image.open(image_path)

# Create a new image with the same size as the original
draw = ImageDraw.Draw(image)
font = ImageFont.load_default()

# Define positions to cover prediction texts (approximate positions for this example)
positions = [(10, 50), (200, 50), (400, 50), (600, 50), (800, 50)]  # Adjust these positions as needed

# Cover prediction texts with white rectangles
for pos in positions:
    draw.rectangle([pos[0], pos[1], pos[0] + 180, pos[1] + 20], fill="white")

# Save the modified image
#modified_image_path = '/mnt/data/01_carousel_SimiExpl_False_no_predictions.png'
#image.save(modified_image_path)
 
image.show()
